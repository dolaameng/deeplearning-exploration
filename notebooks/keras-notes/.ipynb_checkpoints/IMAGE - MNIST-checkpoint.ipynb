# %% [markdown]
# # Summary of Keras Examples on MNIST
#
# - [Keras Code Examples](https://github.com/fchollet/keras/tree/master/examples)

# %% [markdown]
# ### Load Data
# - Good habit to normalize inputs
# - Didn't make the inputs zero-centred

# %%
import keras
# Out:
# Using Theano backend.
# Using gpu device 0: GeForce GTX 980M (CNMeM is disabled, cuDNN 5005)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

# %%
from keras import models, layers, initializations
from keras.utils import np_utils
from keras import backend as K

# %%
from keras.datasets import mnist

mnist = mnist.load_data()
(train_x, train_y), (test_x, test_y) = mnist


train_x = train_x / 255.
test_x = test_x / 255.

print train_x.shape, test_x.shape, train_x.min(), train_x.max()
print train_y.shape, test_y.shape
# Out:
# (60000, 28, 28) (10000, 28, 28) 0.0 1.0
# (60000,) (10000,)

# %%
i = np.random.randint(0, train_x.shape[0])
plt.imshow(train_x[i,:], cmap = plt.cm.gray)
plt.title(train_y[i])

# %%
train_y = np_utils.to_categorical(train_y)
test_y = np_utils.to_categorical(test_y)
print train_y.shape, test_y.shape
# Out:
# (60000, 10) (10000, 10)

# %%
from os import path
import os
import json
def save_model(model, folder_path):
    if not path.exists(folder_path):
        os.mkdir(folder_path)
    json.dump(model.to_json(), open(path.join(folder_path, "model.json"), "w"))
    model.save_weights(path.join(folder_path, "weights.hd5"))
    
def load_model(folder_path):
    model = models.model_from_json(json.load(open(path.join(folder_path, "model.json"))))
    model.load_weights(path.join(folder_path, "weights.hd5"))
    return model

# %% [markdown]
# ## Baseline - MLP
# - ignored

# %% [markdown]
# ## CNN - what features look like
# - shadow VGG-like

# %%
K.image_dim_ordering()
# Out:
# 'th'

# %%
image = layers.Input(shape = (1, 28, 28))


image_model = models.Sequential()
image_model.add(layers.Convolution2D(32, 3, 3, activation="relu", 
                                     input_shape = (1, 28, 28)))
image_model.add(layers.Convolution2D(32, 3, 3, activation="relu"))
image_model.add(layers.MaxPooling2D( (2, 2) ))
image_model.add(layers.Dropout(0.25))
image_model.add(layers.Flatten())

feats = image_model(image)

classifier_model = models.Sequential()
classifier_model.add(layers.Dense(output_dim=128, 
                                  batch_input_shape = image_model.output_shape,
                                  activation = "relu"))
classifier_model.add(layers.Dense(output_dim = 10, activation="softmax"))

scores = classifier_model(feats)

model = models.Model(input = image, output=scores)
model.compile(loss = "categorical_crossentropy", optimizer = "rmsprop", 
         metrics = ["accuracy"])

# %%
model.fit(train_x.reshape(-1, 1, 28, 28), 
          train_y, 
          validation_data = (test_x.reshape(-1, 1, 28, 28), test_y),
          batch_size = 64, nb_epoch = 5)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 9s - loss: 0.1412 - acc: 0.9571 - val_loss: 0.0551 - val_acc: 0.9822
# Epoch 2/5
# 60000/60000 [==============================] - 9s - loss: 0.0496 - acc: 0.9848 - val_loss: 0.0495 - val_acc: 0.9839
# Epoch 3/5
# 60000/60000 [==============================] - 9s - loss: 0.0352 - acc: 0.9893 - val_loss: 0.0332 - val_acc: 0.9884
# Epoch 4/5
# 60000/60000 [==============================] - 9s - loss: 0.0279 - acc: 0.9910 - val_loss: 0.0314 - val_acc: 0.9895
# Epoch 5/5
# 60000/60000 [==============================] - 9s - loss: 0.0220 - acc: 0.9933 - val_loss: 0.0347 - val_acc: 0.9889

# %% [raw]
# save_model(model, "../../models/cnn-mnist/")
# model = load_model("../../models/cnn-mnist/")
# model.compile(loss = "categorical_crossentropy", optimizer = "rmsprop",
#          metrics = ["accuracy"])

# %% [markdown]
# ### image features by cnn

# %%
get_img_feat = K.function(inputs = [image, K.learning_phase()], outputs = [feats])

# %%
i = np.random.randint(0, train_x.shape[0])
img = train_x[i, :].reshape(-1, 1, 28, 28)
img_feat = get_img_feat([img, 0])[0]
img_feat = img_feat.reshape((32, 12, 12))


plt.imshow(img.reshape(28, 28), cmap = plt.cm.gray)

fig, axes = plt.subplots(8, 4, figsize = (1 * 4, 1 * 8))
fig.subplots_adjust(wspace = 0.1, hspace = 0.1)
axes = axes.ravel()
for ax, feat in zip(axes, img_feat):
    ax.imshow(feat, cmap = plt.cm.gray)

# %% [markdown]
# ## Simple RNN with smart Initialization
# - treat an image as a 1D sequence, each element of sequence is a 1D real number (pixel value)
# - based on paper [A Simple Way to Initialize Recurrent Networks of Rectified Linear Units](http://arxiv.org/pdf/1504.00941v2.pdf)
# - Image augmentation?

# %%
from keras.initializations import normal, identity
from keras.optimizers import RMSprop
from keras.callbacks import EarlyStopping

# %%
## sequence of 1D elements
img_seq = layers.Input(shape=(28*28, 1))

hidden_dim = 10 * 10

## simple RNN has power when initialized with identity hidden weights
## for classification, we dont need rnn to return out sequences (only
## the last element in seq is used), but we keep the whole sequence
## for demostration
rnn_model = models.Sequential()
rnn_model.add(layers.SimpleRNN(output_dim=hidden_dim, 
        input_shape=(28*28,1),
        activation ="relu", 
        return_sequences = True,
        init = lambda shape, name: normal(shape, scale=1e-3,name=name),
        inner_init = lambda shape, name: identity(shape, scale=1.,name=name)))
img_rnn_seq = rnn_model(img_seq)

classifier = models.Sequential()
classifier.add(layers.Lambda(lambda batch_seq: batch_seq[:, -1, :], 
                output_shape=lambda batch_seq_shape: (batch_seq_shape[0],hidden_dim),
                batch_input_shape = img_rnn_seq.shape))
# l = layers.Dense(10, activation="softmax")

# probs = l(classifier(img_rnn_seq))
classifier.add(layers.Dense(10, activation="softmax"))
probs = classifier(img_rnn_seq)

model = models.Model(input=img_seq, output = probs)

# %%
model.load_weights("../../models/mnist-irnn-weights.h5")
model.compile(loss = "categorical_crossentropy", 
             optimizer = RMSprop(lr = 1e-6), # much smaller learning rate
             metrics = ["accuracy"])

# %%
## I continously trained it with multiple iteratoins, and total epochs is almost 100
## the keras example reported that 200 epochs gave an accuracy of 96%
model.fit(train_x.reshape((-1, 28*28, 1)), train_y, 
         validation_data = [test_x.reshape(-1, 28*28, 1), test_y],
         batch_size = 64, nb_epoch=3,
         callbacks = [EarlyStopping(patience = 3)],
         verbose = 1)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/3
# 60000/60000 [==============================] - 113s - loss: 0.5915 - acc: 0.7936 - val_loss: 0.6592 - val_acc: 0.7711
# Epoch 2/3
# 60000/60000 [==============================] - 107s - loss: 0.5890 - acc: 0.7938 - val_loss: 0.6887 - val_acc: 0.7636
# Epoch 3/3
# 60000/60000 [==============================] - 106s - loss: 0.5845 - acc: 0.7953 - val_loss: 0.6060 - val_acc: 0.7873

# %%
model.save_weights("../../models/mnist-irnn-weights.h5")
# Out:
# [WARNING] ../../models/mnist-irnn-weights.h5 already exists - overwrite? [y/n]y
# [TIP] Next time specify overwrite=True in save_weights!

# %% [markdown]
# ### what does features in sequence look like?
#
# Casting 100 dim features to a 10 x 10 image doesnt necessarily mean anything - just a way of visualization

# %%
get_rnn_seq = K.function(inputs = [img_seq], outputs = [img_rnn_seq])

# %%
indices = np.random.randint(0, train_x.shape[0], 5)
for i in indices:
    img = train_x[i, :].reshape(-1, 28*28, 1)
    rnn_seq = get_rnn_seq([img])[0].reshape(784, 10, 10)

    #print rnn_seq.shape
    plt.figure(figsize = (1, 1))
    plt.imshow(img.reshape(28, 28), cmap = plt.cm.gray)

    fig, axes = plt.subplots(2, 14, figsize = (1.2 * 14, 1.2 * 2))
    fig.subplots_adjust(wspace = 0.1, hspace = 0.1)
    axes = axes.ravel()
    for i in xrange(0, 28):
        ax = axes[i]
        feat = rnn_seq[i*28,:,:]
        _ = ax.imshow(feat, cmap = plt.cm.gray)
