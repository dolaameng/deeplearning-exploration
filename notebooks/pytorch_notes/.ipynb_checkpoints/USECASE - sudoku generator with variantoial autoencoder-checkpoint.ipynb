# %% [markdown]
# # Use RNN-GAN to generate sudoku
#
# ## dataset
# - [10,000 solved sudoku](http://www.printable-sudoku-puzzles.com/wfiles/)
#
# ## Use variational autoencoder to generate sudoku

# %% [markdown]
# ## Load sudoku training data

# %%
import numpy as np
from glob import glob

import torch
from torch.autograd import Variable
from torch import nn, optim
from torch.utils.data import Dataset, DataLoader

# %%
puzzles = sum([open(f).readlines() 
               for f in glob("/home/dola/data/sudoku/solved/*.txt")], [])
puzzles = [p.strip() for p in puzzles if len(p.strip())==81]
len(puzzles)
# Out:
# 10000

# %%
puzzles[0]
# Out:
# '123456789578139624496872153952381467641297835387564291719623548864915372235748916'

# %% [markdown]
# ### check they are valid sudoku

# %%
def check_sudoku(puzzle):
    assert len(puzzle) == 81
    p = np.array(list(puzzle)).reshape(9, 9)
    rows = range(9)
    cols = range(9)
    digits = set('123456789')
    strides = [slice(0, 3), slice(3, 6), slice(6, 9)]
    squares = [(r, c) for r in strides for c in strides]
    for r in rows:
        assert set(p[r,:]) == digits, "err: row %i" % r
    for c in cols:
        assert set(p[:,c]) == digits, "err: col %i" % c
    for sr, sc in squares:
        assert set(p[sr, sc].ravel()) == digits, "err: sqr %i %i" % (sr, sc)

# %%
# negative example
p = ''.join(['123456789'] * 9)
print(p)
check_sudoku(p)
# Out:
# 123456789123456789123456789123456789123456789123456789123456789123456789123456789
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-5-ecb38c9e82d5> in <module>()
#       2 p = ''.join(['123456789'] * 9)
#       3 print(p)
# ----> 4 check_sudoku(p)
#
# <ipython-input-4-4bbe5d2f0307> in check_sudoku(puzzle)
#      10         assert set(p[r,:]) == digits, "err: row %i" % r
#      11     for c in cols:
# ---> 12         assert set(p[:,c]) == digits, "err: col %i" % c
#      13     for sr, sc in squares:
#      14         assert set(p[sr, sc].ravel()) == digits, "err: sqr %i %i" % (sr, sc)
#
# AssertionError: err: col 0

# %%
for p in puzzles:
    check_sudoku(p)

# %% [markdown]
# ## Data Processing

# %%
# %%time
def augument(puzzles):
    augumented = [p for p in puzzles]
#     augumented += [p[::-1] for p in puzzles]
    for p in puzzles:
        p = np.array(list(p)).reshape([9, 9])
        augumented.append(''.join(np.fliplr(p).ravel()))
        p = p.T
        augumented.append(''.join(p.ravel()))
        augumented.append(''.join(np.fliplr(p).ravel()))
        p = p.T
        augumented.append(''.join(p.ravel()))
        augumented.append(''.join(np.fliplr(p).ravel()))
        p = p.T
        augumented.append(''.join(p.ravel()))
        augumented.append(''.join(np.fliplr(p).ravel()))
    return augumented

puzzles = augument(puzzles)
# Out:
# CPU times: user 1.67 s, sys: 80 ms, total: 1.75 s
# Wall time: 1.63 s

# %%
print(len(puzzles))

for p in puzzles:
    check_sudoku(p)
# Out:
# 80000

# %% [markdown]
# ### cast a puzzle into (9, 9, 9) (channel, width, height) image

# %%
symbol2index = dict(zip('123456789', range(9)))
index2symbol = dict(zip(range(9), '123456789'))

def puzzles2tensor(puzzle_batch):
    batch_size = len(puzzle_batch)
    seq_len = len(puzzle_batch[0])
    t = torch.zeros([batch_size, 9, 9*9])
    for r in range(batch_size):
        for c in range(seq_len):
            s = symbol2index[puzzle_batch[r][c]]
            t[r, s, c] = 1
    return t.view([batch_size, 9, 9, 9])

def tensor2puzzles(tensor):
    """tensor.size() = [batch_size, channel=9, 9, 9]
    """
    batch_size = tensor.size(0)
    t = tensor.view([batch_size, 9, 81])
    _, labels = t.max(dim=1)
    labels = labels.squeeze().numpy()
    return [''.join([index2symbol[l] for l in p]) for p in labels]

# %%
t = puzzles2tensor(puzzles[:5])

# %%
tensor2puzzles(t)
# Out:
# ['123456789578139624496872153952381467641297835387564291719623548864915372235748916',
#  '123456789578913624469728351245361897816297435937845216351672948792184563684539172',
#  '123456789749813562856297134287369415465128397391574826538642971674981253912735648',
#  '123456789489237165765891324852379641634128597971645832596784213348512976217963458',
#  '123456789876139524549827361365798412481265937792314856957682143214573698638941275']

# %%
puzzles[:5]
# Out:
# ['123456789578139624496872153952381467641297835387564291719623548864915372235748916',
#  '123456789578913624469728351245361897816297435937845216351672948792184563684539172',
#  '123456789749813562856297134287369415465128397391574826538642971674981253912735648',
#  '123456789489237165765891324852379641634128597971645832596784213348512976217963458',
#  '123456789876139524549827361365798412481265937792314856957682143214573698638941275']

# %%
class PuzzleSet(Dataset):
    def __init__(self, puzzles):
        """puzzles: puzzle string
        """
        self.data = puzzle2tensor(puzzles)
    def __len__(self):
        return self.data.size(0)
    def __getitem__(self, i):
        return self.data[i, :, :, :]

# %%
puzzle_set = PuzzleSet(puzzles)
len(puzzle_set)
# Out:
# 80000

# %% [markdown]
# ## Variational Encoder

# %%
class VEModel(nn.Module):
    def __init__(self):
        super(VEModel, self).__init__()
        self.encode = nn.Sequential(
            nn.Conv2d(9, 64, kernel_size=3, stride=1, padding=1), # (32, 9, 9)
            nn.ELU(),
            nn.Conv2d(64, 128, kernel_size=3, stride=3), # (64, 3, 3)
            nn.ELU(),
            nn.Conv2d(128, 128, kernel_size=3, stride=3), # (128, 1, 1)
            nn.ELU(),
            nn.BatchNorm2d(128)
        )
        self.mean_layer = nn.Sequential(
            nn.Linear(128, 128),
            nn.ELU(),
            nn.Linear(128, 128)
        )
        self.gamma_layer = nn.Sequential(
            nn.Linear(128, 128),
            nn.ELU(),
            nn.Linear(128, 128)
        )
        self.decode_fc = nn.Sequential(
            nn.Linear(128, 128),
            nn.ELU(),
            nn.BatchNorm1d(128)
        )
        self.decode = nn.Sequential(
            
            nn.ConvTranspose2d(128, 128, kernel_size=3, stride=3),
            nn.ELU(),
            nn.ConvTranspose2d(128, 64, kernel_size=3, stride=3),
            nn.ELU(),
            nn.ConvTranspose2d(64, 9, kernel_size=1, stride=1),
            nn.Sigmoid()
        )
    def forward(self, x):
        out = self.encode(x)
        out = out.squeeze()
        self.mean = self.mean_layer(out)
        self.gamma = self.gamma_layer(out)
        sigma = torch.exp(0.5 * self.gamma)
        noise = Variable(torch.randn(sigma.size())).cuda()
        h = self.mean + sigma * noise
        h = self.decode_fc(h)
        h = h.view([h.size(0), h.size(1), 1, 1])
        h = self.decode(h)
        return h

# %%
m = VEModel().cuda()
x = Variable(torch.rand([6, 9, 9, 9])).cuda()
y = m(x)

# %%
y.size()
# Out:
# torch.Size([6, 9, 9, 9])

# %%
tensor2puzzles(y.cpu().data)
# Out:
# ['222222222222222222222222222222222222222222222222222222222222222222222222222222222',
#  '222222222222222222222222222222222222222222222222222222222222222222222222222222222',
#  '222222222222222222222222222222222222222222222222222222222222222222222222222222222',
#  '222222222222222222222222222222222222222222222222222222222222222222222222222222222',
#  '222222222222222222222222222222222222222222222222222222222222222222222222222222222',
#  '222222222222222222222222222222222222222222222222222222222222222222222222222222222']

# %% [markdown]
# ## training

# %%
objective = nn.BCELoss()#nn.MSELoss()

# def objective(yhat, y):
#     ## construction loss
#     reconstruction_loss = nn.BCELoss(yhat.view([-1, 9*9*9]), y.view([-1, 9*9*9]))
#     latent_loss =

# %%
n_epochs = 10
batch_size = 128
train_batches = DataLoader(puzzle_set,
                           batch_size=batch_size,
                           shuffle=True,
                           num_workers=4)

model = VEModel().cuda()
optimizer = optim.Adam(model.parameters(), lr=5e-4)

model.train()

for epoch in range(n_epochs):
    for b, x_batch in enumerate(train_batches):
        x = Variable(x_batch).cuda()
        
        model.zero_grad()
        y = model(x)
        reconstruction_loss = objective(y.view([-1, 9*9*9]),
                                        x.view([-1, 9*9*9]))
        latent_loss = 5 * torch.mean(torch.exp(model.gamma) + 
                                       model.mean*model.mean 
                                       - 1 - model.gamma)
        loss = reconstruction_loss + latent_loss
        loss.backward()
        optimizer.step()
        
        if b % 200 == 0:
            print(epoch, b, loss.data[0], reconstruction_loss.data[0], latent_loss.data[0])
# Out:
# 0 0 0.9352810382843018 0.7017669677734375 0.23351404070854187
# 0 200 0.35027334094047546 0.34987759590148926 0.0003957526059821248
# 0 400 0.3471774160861969 0.34697672724723816 0.00020067600416950881
# 0 600 0.3370785415172577 0.3369792699813843 9.926914935931563e-05
# 1 0 0.3369148075580597 0.33679401874542236 0.00012079084990546107
# 1 200 0.3348923325538635 0.3348245620727539 6.778082752134651e-05
# 1 400 0.3338508605957031 0.33381104469299316 3.9808888686820865e-05
# 1 600 0.3339959979057312 0.3339560329914093 3.99576747440733e-05
# 2 0 0.3333566188812256 0.33331871032714844 3.7919504393357784e-05
# 2 200 0.3331468999385834 0.3331150710582733 3.1823987228563055e-05
# 2 400 0.3342674672603607 0.33424654603004456 2.0933453924953938e-05
# 2 600 0.3340589106082916 0.3340369462966919 2.1970245143165812e-05
# 3 0 0.33368542790412903 0.33366551995277405 1.9898365280823782e-05
# 3 200 0.3335511386394501 0.3335331976413727 1.792836883396376e-05
# 3 400 0.3341186046600342 0.3341030478477478 1.5567704394925386e-05
# 3 600 0.33487406373023987 0.33486199378967285 1.205547869176371e-05
# 4 0 0.33380529284477234 0.3337939977645874 1.1305564839858562e-05
# 4 200 0.3335568904876709 0.3335459232330322 1.0960502550005913e-05
# 4 400 0.3326435983181 0.33263227343559265 1.1326234016451053e-05
# 4 600 0.3340719938278198 0.3340626060962677 9.393242180522066e-06
# 5 0 0.33365726470947266 0.33364835381507874 8.914123100112192e-06
# 5 200 0.33410370349884033 0.33409228920936584 1.1428509424149524e-05
# 5 400 0.3344379663467407 0.3344269096851349 1.106720264942851e-05
# 5 600 0.33372849225997925 0.33371880650520325 9.680890798335895e-06
# 6 0 0.33447399735450745 0.3344665467739105 7.465284852514742e-06
# 6 200 0.3334551155567169 0.3334483504295349 6.756269613106269e-06
# 6 400 0.33413171768188477 0.33412277698516846 8.93665219336981e-06
# 6 600 0.3336518704891205 0.33364319801330566 8.658551450935192e-06
# 7 0 0.3336764872074127 0.3336683213710785 8.163557140505873e-06
# 7 200 0.33469051122665405 0.3346811830997467 9.319042874267325e-06
# 7 400 0.33401134610176086 0.33400362730026245 7.724178431089967e-06
# 7 600 0.3340458273887634 0.33404067158699036 5.156549377716146e-06
# 8 0 0.3339686691761017 0.333963006734848 5.6684966693865135e-06
# 8 200 0.3325549066066742 0.3325497806072235 5.112179223942803e-06
# 8 400 0.3338201344013214 0.33381471037864685 5.411888650996843e-06
# 8 600 0.3337872326374054 0.33378028869628906 6.931164534762502e-06
# 9 0 0.3332384526729584 0.3332337737083435 4.670424004871165e-06
# 9 200 0.33327242732048035 0.33326616883277893 6.2654535213368945e-06
# 9 400 0.3335975110530853 0.3335915207862854 5.994534149067476e-06
# 9 600 0.33356359601020813 0.333560049533844 3.5489415495248977e-06

# %% [markdown]
# ### I Cannot even overfit the data!

# %%
tensor2puzzles(y.cpu().data)
# Out:
# ['187656781254311552344222643439565974512464175679545836731968237811975218932868219',
#  '187654781254311552344222653419565974512464275679545836711968217811975118932868219',
#  '187456781254311542344222643419565834512464975679545836711949237811975118932868219',
#  '187454781254311542344222643419565874512464175679545836731969237811775218932868119',
#  '187456781254311552344222653479565134512464175679545836711968237811775218932868219',
#  '187456781254311552344222653418565134512464275638545836711968237811975118932868219',
#  '187656781254311542354222653412565974518464275639545216731968217861975118932868219',
#  '187654781264311542344222643419565974532464175639545816711965237811565118932868219',
#  '187456781254311542344222653419565974512464175679545816732968237811565118932868219',
#  '187456781254311452344222653411565934512464975639545836731868217811775118932868219',
#  '187656781254311552344222653419565874512464275679545236711965237811775118936865219',
#  '187656781254311552344222653418565974532464275679545816731968217811775218932868219',
#  '187656781264311552344222653411565974512464975639545836732968237811975218932868119',
#  '187656781254311552354222643411565934512464275639545216711965237811965218936868219',
#  '187656781254311552344222653419565974512464175671545836732968237811975118932868219',
#  '187656781254311542344222643439565174592464275678545816731968237811975218932868219',
#  '187656781254311552354222643411565974512464275679545816731968237811975218932868219',
#  '187456781254311552344222643418565974512464275639545836731968217811775218932868219',
#  '187656781264311552344222643412565974518464275679545816731968237811765118932868219',
#  '187656781264311552354222653419565874512464175679545836731965217811775218932868219',
#  '187656781254311542344222653472565974512464275679545816711968237811975118932868119',
#  '187656781254311552344222653418565974512464275679545816711968217811975118932868219',
#  '187656781264311552344222653412565874532464175699545836731968217811775218932868219',
#  '187456781254311552354222653419565874512464975679545836711969237851975118936868119',
#  '187656781254311552344222653479565174512464275699545836711968217811975118932868219',
#  '187456781254311542344222643419565174532464275679545836731968237811775218932868219',
#  '187656781254311542354222643411565974512464175679545836731965217811975218932868219',
#  '187656781254311542344222653411565934512464175679545836732968237811975118932868119',
#  '187654781254311542344222653419565874592464175679545816711968237811775118932868219',
#  '187654781254311452344222653411565174512464275639545816712965217811775218932868219',
#  '187656781254311552344222653411565934512464975639545836732968217811775218932868119',
#  '187656781254311552344222653411565974532464175639545836731965217811775218932868219',
#  '187656781254311552344222653419565174512464275679545836731968217811775218932868219',
#  '187656781264311552344222653412565934512464975639545816731969237811975218932868219',
#  '187456781264311552344222653411565934512464975639545816731868217811775218932868219',
#  '187656781254311552344222653412565134512464275639545816711968217811975118932868219',
#  '187656781264311552344222653412565974532464175639545836731968237811975218932868119',
#  '187456781254311542344222643431565874512464175679545836732969237811775218932868219',
#  '187456781254311542344222643419565974512464175678545816752969217811975218932868219',
#  '187656781254311552344222653411565174532464275679545816731968217811775218932868219',
#  '187656781254311542344222643419565134512464275679545836731965237811775218932868219',
#  '187656781264311552344222653411565934512464175639545816711968237812775118932868219',
#  '187656781254311542354222643419565874512464175671545836731969217852965118936868219',
#  '187654781254311552354222653419565874532464275679545836731968217812775218932868219',
#  '187656781254311452354222663411565974512464175639545836732965217811775118932868219',
#  '187456781254311552344222643419565974512464175639545836711965237811975118932868119',
#  '187656781255311552356222653412565974512464275639545116731968217811975118932868219',
#  '187656781254311542344222653411565974512464175679545816731968217811775218932868219',
#  '187654781266311552344222643419565974512464175679545816711968237811775218932868119',
#  '187654781254311552356222643419565174519464275671545836731968217812775118932868219',
#  '187654781264311542344222643411565974532464115639545816731968217811775218932868219',
#  '187454781264311552344222653439565874512464175679545836711969237811575218932868219',
#  '187656781254311542356222653419565974512464175671545816732965237811965118932868219',
#  '187454781264311552344222653411565974512464275639545836711968237811975218932868219',
#  '187656781264311552344222653419565974512464175679545836731965237811975118932868219',
#  '187656781254311552354222653412565974512464275639545836731868217811975118932868219',
#  '187654781264311542344222643411565974512464275679545836731968117811975218932868219',
#  '187456781254311542344222643479565134512464275679545836711965237812775218932868119',
#  '187656781254311542344222653479565174512464275679545836731968217811775218932868219',
#  '187456781254311552344222653419565874512464175679545836731968217811775118932868219',
#  '187656781254311552344222653419565134512464275679545836711968237811975118932868219',
#  '187656781254311552344222653439565174512464175679545836711968217811775118932868219',
#  '187456781264311552344222653419565834512464175679545836731949237812975218932868119',
#  '187656781254311552344222653411565974512464175679545836731968217811975218932868219',
#  '187654781254311542344222653419565974512464275679545816731969237811565218932868119',
#  '187656781264311552344222653411565834512464175639545836711868217811975218932868219',
#  '187656781264311552344122663471565834512464275679545836731969217811765218932868119',
#  '187656781264311552344222643419565174532464275679545816711968237811975218936868219',
#  '187456781254311542344222643412565874592464275679545836731968217811775218932868219',
#  '187656781264311542344222643411565974512464175639545816711968237811965118932868119',
#  '187656781254311552344222653412565974512464275679545836731968217811775218932868219',
#  '187656781254311552344222653412565174512464275679545236731968217811775218931868219',
#  '187656781254311552344222653411565974512464175639545816712968217811975118932868219',
#  '187656781254311542344222643412565174532464275679545816732968237811765118932868219',
#  '187656781255311442356222653419565874512464275679545836731969237811765118932868219',
#  '187654781254311542344222643439565974532464275679545836731965117811775218932868219',
#  '187654781254311552354222653418565974532464275639545816711965217812775218936868219',
#  '187656781254311442344222643419565874512464175679545836711968237811775218932868219',
#  '187656781264311552344222653419565874512464175679545816711968237811765118932868219',
#  '187656781254311452354222653411565874512464175679545836732968237811775218932868219',
#  '187656781254311552344222653479565974512464275679545816712968237811775118932868119',
#  '187654781254311552344222653419565174512464275679545216731969217811975118932868219',
#  '187656781254311552344222653419565134512464275679545836731968217811975218932868219',
#  '187456781264311552344222643419565974512464175679545816731969237811975118932868219',
#  '187656781254311552344222643411565974512464275639545836711968237811975218932868219',
#  '187656781254311552344222653419565834512464175679545836711968237811765118932868119',
#  '187656781254311442344222653411565974512464175679545836732968217811775218932868219',
#  '187656781254311552356222653419565174512464275679545836731969217811975118932868219',
#  '187456781254311542354222643479565174519464275671545836731968237812775118932868219',
#  '187656781254311552344222643419565134512464275679545836731965217811975218932868219',
#  '187656781254311542346222643439565974512464275679545216712969237811975118932868219',
#  '187456781254311542344222643412565974512464175639545816731968237811975218932868219',
#  '187654781254311552344222653412565874518464275679545836711968237811775118932868119',
#  '187656781254311542344222643419565974512464275679545816731968237811975118932868219',
#  '187656781254311542344222653439565934599464175678545836732969217811975218932868219',
#  '187656781264311552344222643419565974512464175639545816731968237811965118932868219',
#  '187656781264311542354222643411565974512464275679545816732965217811765218932568219',
#  '187656781254311542344222643419565934512464175679545836711969237812965118932868219',
#  '187656781254311552344222643419565974512464275671545816731968217811975118932868219',
#  '187456781254311542344222653439565934512464275679545836731969237811975218932868119',
#  '187656781254311552344222653419565174512464275679545836731968237811775218932868219',
#  '187656781264311552344122653411565974518464175639545816731968217811965118932868119',
#  '187456781254311552344222653411565834512464175679545836731968217811975218932868219',
#  '187654781264311552344222653411565174512464275679545216731968217811775218932868219',
#  '187656781254311542344222643439565874512464275679545836731968237811975118932868219',
#  '187456781254311542354222643419565974532464175679545816731968237811965218932868219',
#  '187456781254311552344222653419565974512464175679545836731968237811965118932868219',
#  '187456781264311542344222643411565974592464175671545836732968217811775218932868219',
#  '187656781254311552344222653419565174512464275679545816711968237811975118932868119',
#  '187654781254311542354222653419565934512464275679545836711968237811975218932868219',
#  '187654781254311542344222653411565934512464175679545816732969237811765118932868119',
#  '187656781254311542344222653412565174532464275639545816711968237812975118932868219',
#  '187656781254311552346222653419565974512464175671545836711949217811775118932868219',
#  '187656781264311552354122653419565874512464175679545836731868237811775218932868219',
#  '187656781264313552344222653411565934512464175639545816731969217811975118932868219',
#  '187656781254311542346222653439565934512464275679545836731969217811975218932868219',
#  '187656781254311542344222653419565874532464275679545836732965117811775218932868219',
#  '187656781254311552356222663479565834512464275671545836711968237812975118935868219',
#  '187654781264311552344222643439565974512464275679545836731968217811975218932868219',
#  '187656781264311542344222643439565974512464275679545816732968217811775218932868219',
#  '187654781254311542344222643439565174512464275679545836731968237811775218932868219',
#  '187456781254311552344222653411565974512464275679545816731968237811775118932868219',
#  '187656781254311542344222643419565874532464175671545836712968237811975118932868219',
#  '187654781264311552354222653411565934512464175639545836731969217811965118932868219',
#  '187456781264311552344222653412565974518464275639545836731965117811775218932868219',
#  '187656781254311442344222563412565174512464275679545836731968217812775218932868219',
#  '187456781254311552354222653419565874512464175679545836732965237811765118932868219',
#  '187456781254311552344222653479565834512464175678545836731969237811975118932868219']
